# %% [markdown]
# # Installation of MySQL

# %% [markdown]
# ## Downloading packages and starting the service

# %% [markdown]
# ![mySQL%20installation.PNG](attachment:mySQL%20installation.PNG)

# %% [markdown]
# ## Login to the service with root user

# %% [markdown]
# ![rootLogin.PNG](attachment:rootLogin.PNG)

# %% [markdown]
# # Manipulate MySQL

# %% [markdown]
# ## Creating a database and add user

# %% [markdown]
# ![createDB.PNG](attachment:createDB.PNG)

# %% [markdown]
# ![createUser.PNG](attachment:createUser.PNG)

# %% [markdown]
# ## Basic commands on databases

# %% [markdown]
# ![sqlCommand1.PNG](attachment:sqlCommand1.PNG)

# %% [markdown]
# ![sqlCommand2.PNG](attachment:sqlCommand2.PNG)

# %% [markdown]
# ![sqlCommand3.PNG](attachment:sqlCommand3.PNG)
